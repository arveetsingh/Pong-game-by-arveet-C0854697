# %% [markdown]
# #Training Pong with varying neurons and learning rate

# %%
# !apt-get install python-opengl -y  >/dev/null
# !apt install xvfb -y >/dev/null

# %%
# !pip install pyvirtualdisplay >/dev/null
# !pip install piglet >/dev/null

# %%
# from pyvirtualdisplay import Display
# display = Display(visible=0, size=(1400, 900))
# display.start()

# %%
# !pip install gym >/dev/null

# %%
# !pip install JSAnimation >/dev/null

# %%
# %matplotlib inline
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
import matplotlib.pyplot as plt
from IPython.display import HTML


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 144)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
    HTML(anim.to_jshtml())

# %% [markdown]
# ## Step 2: Playing Pong

# %%
# %pip install -U gym>=0.21.0
# %pip install -U gym[atari,accept-rom-license]
import gym
env = gym.make('Pong-v0')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[accept-rom-license,atari] in /usr/local/lib/python3.7/dist-packages (0.25.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (1.3.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (0.0.8)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (1.21.6)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (4.12.0)
# Collecting ale-py~=0.7.5
#   Downloading ale_py-0.7.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 25.0 MB/s
# Collecting autorom[accept-rom-license]~=0.4.2
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from ale-py~=0.7.5->gym[accept-rom-license,atari]) (5.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (4.64.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.23.0)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.4.2.tar.gz (9.8 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[accept-rom-license,atari]) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[accept-rom-license,atari]) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.10)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (PEP 517) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.4.2-py3-none-any.whl size=441027 sha256=3f88362432e0aa66d71a6f7ba1956f51ce264bb7fcb5094f1ae2dd8d54502732
#   Stored in directory: /root/.cache/pip/wheels/87/67/2e/6147e7912fe37f5408b80d07527dab807c1d25f5c403a9538a
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom, ale-py
# Successfully installed AutoROM.accept-rom-license-0.4.2 ale-py-0.7.5 autorom-0.4.2
# /usr/local/lib/python3.7/dist-packages/gym/envs/registration.py:594: UserWarning: WARN: The environment Pong-v0 is out of date. You should consider upgrading to version `v4`.
#   f"The environment {id} is out of date. You should consider "
# /usr/local/lib/python3.7/dist-packages/gym/core.py:330: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/step_api_compatibility.py:40: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."

# %%
env.action_space
# Out:
# Discrete(6)

# %%
env.observation_space
# Out:
# Box(0, 255, (210, 160, 3), uint8)

# %%
# Run a demo of the environment
observation = env.reset()
cumulated_reward = 0

frames = []
for t in range(1000):
#     print(observation)
    frames.append(env.render(mode = 'rgb_array'))
    # very stupid agent, just makes a random action within the allowd action space
    action = env.action_space.sample()
#     print("Action: {}".format(t+1))    
    observation, reward, done, info = env.step(action)
#     print(reward)
    cumulated_reward += reward
    if done:
        print("Episode finished after {} timesteps, accumulated reward = {}".format(t+1, cumulated_reward))
        break
print("Episode finished without success, accumulated reward = {}".format(cumulated_reward))

env.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/core.py:52: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   "The argument mode in render method is deprecated; "
# /usr/local/lib/python3.7/dist-packages/gym/utils/passive_env_checker.py:298: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   "No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps."
# /usr/local/lib/python3.7/dist-packages/gym/utils/passive_env_checker.py:228: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   "Core environment is written in old step API which returns one bool instead of two. "
# Episode finished without success, accumulated reward = -14.0

# %%
def sigmoid(x): 
  return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

def prepro(I):
  """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
  I = I[35:195] # crop
  I = I[::2,::2,0] # downsample by factor of 2
  I[I == 144] = 0 # erase background (background type 1)
  I[I == 109] = 0 # erase background (background type 2)
  I[I != 0] = 1 # everything else (paddles, ball) just set to 1
  return I.astype(np.float).ravel()

def policy_forward(x):
  h = np.dot(model['W1'], x)
  h[h<0] = 0 # ReLU nonlinearity
  logp = np.dot(model['W2'], h)
  p = sigmoid(logp)
  return p, h # return probability of taking action 2, and hidden state

def model_step(model, observation, prev_x):
  # preprocess the observation, set input to network to be difference image
  cur_x = prepro(observation)
  x = cur_x - prev_x if prev_x is not None else np.zeros(D)
  prev_x = cur_x
  
  # forward the policy network and sample an action from the returned probability
  aprob, _ = policy_forward(x)
  action = 2 if aprob >= 0.5 else 3 # roll the dice!
  
  return action, prev_x

def play_game(env, model):
  observation = env.reset()

  frames = []
  cumulated_reward = 0

  prev_x = None # used in computing the difference frame

  for t in range(1000):
      frames.append(env.render(mode = 'rgb_array'))
      action, prev_x = model_step(model, observation, prev_x)
      observation, reward, done, info = env.step(action)
      cumulated_reward += reward
      if done:
          print("Episode finished after {} timesteps, accumulated reward = {}".format(t+1, cumulated_reward))
          break
  print("Episode finished without success, accumulated reward = {}".format(cumulated_reward))
  env.close()
  display_frames_as_gif(frames)

# %% [markdown]
# ## Step 3: Policy Gradient from Scratch

# %%
import numpy as np

# model initialization
H = 200 # number of hidden layer neurons
D = 80 * 80 # input dimensionality: 80x80 grid
model = {}
model['W1'] = np.random.randn(H,D) / np.sqrt(D) # "Xavier" initialization
model['W2'] = np.random.randn(H) / np.sqrt(H)

# import pickle
# model = pickle.load(open('model.pkl', 'rb'))

# %%
# hyperparameters
batch_size = 10 # every how many episodes to do a param update?
# learning_rate = 1e-4
learning_rate = 1e-4
 
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
  
grad_buffer = { k : np.zeros_like(v) for k,v in model.items() } # update buffers that add up gradients over a batch
rmsprop_cache = { k : np.zeros_like(v) for k,v in model.items() } # rmsprop memory

def discount_rewards(r):
  """ take 1D float array of rewards and compute discounted reward """
  discounted_r = np.zeros_like(r, dtype=np.float32)
  running_add = 0
  for t in reversed(range(0, r.size)):
    if r[t] != 0: running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
    running_add = running_add * gamma + r[t]
    discounted_r[t] = running_add
  return discounted_r

def policy_backward(epx, eph, epdlogp):
  """ backward pass. (eph is array of intermediate hidden states) """
  dW2 = np.dot(eph.T, epdlogp).ravel()
  dh = np.outer(epdlogp, model['W2'])
  dh[eph <= 0] = 0 # backpro prelu
  dW1 = np.dot(dh.T, epx)
  return {'W1':dW1, 'W2':dW2}

def train_model(env, model, total_episodes = 100):
  hist = []
  observation = env.reset()

  prev_x = None # used in computing the difference frame
  xs,hs,dlogps,drs = [],[],[],[]
  running_reward = None
  reward_sum = 0
  episode_number = 0

  while True:
    # preprocess the observation, set input to network to be difference image
    cur_x = prepro(observation)
    x = cur_x - prev_x if prev_x is not None else np.zeros(D)
    prev_x = cur_x

    # forward the policy network and sample an action from the returned probability
    aprob, h = policy_forward(x)
    action = 2 if np.random.uniform() < aprob else 3 # roll the dice!

    # record various intermediates (needed later for backprop)
    xs.append(x) # observation
    hs.append(h) # hidden state
    y = 1 if action == 2 else 0 # a "fake label"
    dlogps.append(y - aprob) # grad that encourages the action that was taken to be taken (see http://cs231n.github.io/neural-networks-2/#losses if confused)

    # step the environment and get new measurements
    observation, reward, done, info = env.step(action)
    reward_sum += reward

    drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

    if done: # an episode finished
      episode_number += 1

      # stack together all inputs, hidden states, action gradients, and rewards for this episode
      epx = np.vstack(xs)
      eph = np.vstack(hs)
      epdlogp = np.vstack(dlogps)
      epr = np.vstack(drs)
      xs,hs,dlogps,drs = [],[],[],[] # reset array memory

      # compute the discounted reward backwards through time
      discounted_epr = discount_rewards(epr)
      # standardize the rewards to be unit normal (helps control the gradient estimator variance)
      discounted_epr -= np.mean(discounted_epr)
      discounted_epr /= np.std(discounted_epr)

      epdlogp *= discounted_epr # modulate the gradient with advantage (PG magic happens right here.)
      grad = policy_backward(epx, eph, epdlogp)
      for k in model: grad_buffer[k] += grad[k] # accumulate grad over batch

      # perform rmsprop parameter update every batch_size episodes
      if episode_number % batch_size == 0:
        for k,v in model.items():
          g = grad_buffer[k] # gradient
          rmsprop_cache[k] = decay_rate * rmsprop_cache[k] + (1 - decay_rate) * g**2
          model[k] += learning_rate * g / (np.sqrt(rmsprop_cache[k]) + 1e-5)
          grad_buffer[k] = np.zeros_like(v) # reset batch gradient buffer

      # keeping record
      running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
      hist.append((episode_number, reward_sum, running_reward))
      plt.scatter(episode_number, running_reward, marker=".")
      print ('resetting env. episode %f, reward total was %f. running mean: %f' % (episode_number, reward_sum, running_reward))
      reward_sum = 0
      observation = env.reset() # reset env
      prev_x = None
      if episode_number == total_episodes: 
        return hist
        return plt.show()
        


  #   if reward != 0: # Pong has either +1 or -1 reward exactly when game ends.
  #     print (('ep %d: game finished, reward: %f' % (episode_number, reward)) + ('' if reward == -1 else ' !!!!!!!!'))

# %%
# %time hist1 = train_model(env, model, total_episodes=1000)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# resetting env. episode 1.000000, reward total was -21.000000. running mean: -21.000000
# resetting env. episode 2.000000, reward total was -21.000000. running mean: -21.000000
# resetting env. episode 3.000000, reward total was -21.000000. running mean: -21.000000
# resetting env. episode 4.000000, reward total was -21.000000. running mean: -21.000000
# resetting env. episode 5.000000, reward total was -21.000000. running mean: -21.000000
# resetting env. episode 891.000000, reward total was -21.000000. running mean: -20.425468
# resetting env. episode 892.000000, reward total was -21.000000. running mean: -20.431213
# resetting env. episode 893.000000, reward total was -21.000000. running mean: -20.436901
# resetting env. episode 894.000000, reward total was -21.000000. running mean: -20.442532
# resetting env. episode 895.000000, reward total was -20.000000. running mean: -20.438107
# resetting env. episode 896.000000, reward total was -20.000000. running mean: -20.433726
# resetting env. episode 897.000000, reward total was -21.000000. running mean: -20.439388
# resetting env. episode 898.000000, reward total was -20.000000. running mean: -20.434995
# resetting env. episode 899.000000, reward total was -21.000000. running mean: -20.440645
# resetting env. episode 900.000000, reward total was -20.000000. running mean: -20.436238
# resetting env. episode 901.000000, reward total was -19.000000. running mean: -20.421876
# resetting env. episode 902.000000, reward total was -21.000000. running mean: -20.427657
# resetting env. episode 903.000000, reward total was -21.000000. running mean: -20.433380
# resetting env. episode 904.000000, reward total was -21.000000. running mean: -20.439047
# resetting env. episode 905.000000, reward total was -21.000000. running mean: -20.444656
# resetting env. episode 906.000000, reward total was -20.000000. running mean: -20.440210
# resetting env. episode 907.000000, reward total was -20.000000. running mean: -20.435808
# resetting env. episode 908.000000, reward total was -20.000000. running mean: -20.431449
# resetting env. episode 909.000000, reward total was -20.000000. running mean: -20.427135
# resetting env. episode 910.000000, reward total was -21.000000. running mean: -20.432864
# resetting env. episode 911.000000, reward total was -20.000000. running mean: -20.428535
# resetting env. episode 912.000000, reward total was -20.000000. running mean: -20.424250
# resetting env. episode 913.000000, reward total was -21.000000. running mean: -20.430007
# resetting env. episode 914.000000, reward total was -19.000000. running mean: -20.415707
# resetting env. episode 915.000000, reward total was -21.000000. running mean: -20.421550
# resetting env. episode 916.000000, reward total was -20.000000. running mean: -20.417334
# resetting env. episode 917.000000, reward total was -21.000000. running mean: -20.423161
# resetting env. episode 918.000000, reward total was -19.000000. running mean: -20.408930
# resetting env. episode 919.000000, reward total was -21.000000. running mean: -20.414840
# resetting env. episode 920.000000, reward total was -20.000000. running mean: -20.410692
# resetting env. episode 921.000000, reward total was -21.000000. running mean: -20.416585
# resetting env. episode 922.000000, reward total was -20.000000. running mean: -20.412419
# resetting env. episode 923.000000, reward total was -21.000000. running mean: -20.418295
# resetting env. episode 924.000000, reward total was -19.000000. running mean: -20.404112
# resetting env. episode 925.000000, reward total was -21.000000. running mean: -20.410071
# resetting env. episode 926.000000, reward total was -21.000000. running mean: -20.415970
# resetting env. episode 927.000000, reward total was -20.000000. running mean: -20.411810
# resetting env. episode 928.000000, reward total was -21.000000. running mean: -20.417692
# resetting env. episode 929.000000, reward total was -20.000000. running mean: -20.413515
# resetting env. episode 930.000000, reward total was -21.000000. running mean: -20.419380
# resetting env. episode 931.000000, reward total was -21.000000. running mean: -20.425186
# resetting env. episode 932.000000, reward total was -20.000000. running mean: -20.420935
# resetting env. episode 933.000000, reward total was -19.000000. running mean: -20.406725
# resetting env. episode 934.000000, reward total was -21.000000. running mean: -20.412658
# resetting env. episode 935.000000, reward total was -20.000000. running mean: -20.408531
# resetting env. episode 982.000000, reward total was -18.000000. running mean: -20.349053
# resetting env. episode 983.000000, reward total was -19.000000. running mean: -20.335563
# resetting env. episode 984.000000, reward total was -21.000000. running mean: -20.342207
# resetting env. episode 985.000000, reward total was -21.000000. running mean: -20.348785
# resetting env. episode 986.000000, reward total was -21.000000. running mean: -20.355297
# resetting env. episode 987.000000, reward total was -21.000000. running mean: -20.361744
# resetting env. episode 988.000000, reward total was -20.000000. running mean: -20.358127
# resetting env. episode 989.000000, reward total was -19.000000. running mean: -20.344545
# resetting env. episode 990.000000, reward total was -21.000000. running mean: -20.351100
# resetting env. episode 991.000000, reward total was -19.000000. running mean: -20.337589
# resetting env. episode 992.000000, reward total was -21.000000. running mean: -20.344213
# resetting env. episode 993.000000, reward total was -19.000000. running mean: -20.330771
# resetting env. episode 994.000000, reward total was -21.000000. running mean: -20.337463
# resetting env. episode 995.000000, reward total was -21.000000. running mean: -20.344089
# resetting env. episode 996.000000, reward total was -19.000000. running mean: -20.330648
# resetting env. episode 997.000000, reward total was -20.000000. running mean: -20.327341
# resetting env. episode 998.000000, reward total was -20.000000. running mean: -20.324068
# resetting env. episode 999.000000, reward total was -21.000000. running mean: -20.330827
# resetting env. episode 1000.000000, reward total was -21.000000. running mean: -20.337519
# CPU times: user 59min 31s, sys: 26min 8s, total: 1h 25min 40s
# Wall time: 44min 31s

# %%
play_game(env, model)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# Episode finished without success, accumulated reward = -7.0

# %%
# %time hist2 = train_model(env, model, total_episodes=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# resetting env. episode 1.000000, reward total was -20.000000. running mean: -20.000000
# resetting env. episode 2.000000, reward total was -21.000000. running mean: -20.010000
# resetting env. episode 3.000000, reward total was -21.000000. running mean: -20.019900
# resetting env. episode 4.000000, reward total was -20.000000. running mean: -20.019701
# resetting env. episode 5.000000, reward total was -20.000000. running mean: -20.019504
# resetting env. episode 6.000000, reward total was -21.000000. running mean: -20.029309
# resetting env. episode 7.000000, reward total was -20.000000. running mean: -20.029016
# resetting env. episode 8.000000, reward total was -20.000000. running mean: -20.028726
# resetting env. episode 9.000000, reward total was -20.000000. running mean: -20.028438
# resetting env. episode 10.000000, reward total was -21.000000. running mean: -20.038154
# resetting env. episode 11.000000, reward total was -18.000000. running mean: -20.017773
# resetting env. episode 12.000000, reward total was -21.000000. running mean: -20.027595
# resetting env. episode 13.000000, reward total was -20.000000. running mean: -20.027319
# resetting env. episode 14.000000, reward total was -21.000000. running mean: -20.037046
# resetting env. episode 15.000000, reward total was -21.000000. running mean: -20.046675
# resetting env. episode 16.000000, reward total was -21.000000. running mean: -20.056208
# resetting env. episode 17.000000, reward total was -20.000000. running mean: -20.055646
# resetting env. episode 18.000000, reward total was -19.000000. running mean: -20.045090
# resetting env. episode 19.000000, reward total was -21.000000. running mean: -20.054639
# resetting env. episode 20.000000, reward total was -21.000000. running mean: -20.064093
# resetting env. episode 21.000000, reward total was -21.000000. running mean: -20.073452
# resetting env. episode 22.000000, reward total was -17.000000. running mean: -20.042717
# resetting env. episode 23.000000, reward total was -21.000000. running mean: -20.052290
# resetting env. episode 24.000000, reward total was -21.000000. running mean: -20.061767
# resetting env. episode 25.000000, reward total was -20.000000. running mean: -20.061149
# resetting env. episode 26.000000, reward total was -21.000000. running mean: -20.070538
# resetting env. episode 27.000000, reward total was -21.000000. running mean: -20.079833
# resetting env. episode 28.000000, reward total was -21.000000. running mean: -20.089034
# resetting env. episode 29.000000, reward total was -20.000000. running mean: -20.088144
# resetting env. episode 30.000000, reward total was -21.000000. running mean: -20.097262
# resetting env. episode 31.000000, reward total was -21.000000. running mean: -20.106290
# resetting env. episode 32.000000, reward total was -20.000000. running mean: -20.105227
# resetting env. episode 33.000000, reward total was -21.000000. running mean: -20.114175
# resetting env. episode 34.000000, reward total was -21.000000. running mean: -20.123033
# resetting env. episode 35.000000, reward total was -21.000000. running mean: -20.131803
# resetting env. episode 36.000000, reward total was -21.000000. running mean: -20.140485
# resetting env. episode 37.000000, reward total was -21.000000. running mean: -20.149080
# resetting env. episode 38.000000, reward total was -21.000000. running mean: -20.157589
# resetting env. episode 39.000000, reward total was -21.000000. running mean: -20.166013
# resetting env. episode 40.000000, reward total was -21.000000. running mean: -20.174353
# resetting env. episode 41.000000, reward total was -20.000000. running mean: -20.172609
# resetting env. episode 42.000000, reward total was -19.000000. running mean: -20.160883
# resetting env. episode 43.000000, reward total was -20.000000. running mean: -20.159274
# resetting env. episode 44.000000, reward total was -21.000000. running mean: -20.167682
# resetting env. episode 45.000000, reward total was -19.000000. running mean: -20.156005
# resetting env. episode 46.000000, reward total was -20.000000. running mean: -20.154445
# resetting env. episode 47.000000, reward total was -21.000000. running mean: -20.162900
# resetting env. episode 48.000000, reward total was -20.000000. running mean: -20.161271
# resetting env. episode 49.000000, reward total was -20.000000. running mean: -20.159659
# resetting env. episode 50.000000, reward total was -21.000000. running mean: -20.168062
# CPU times: user 2min 55s, sys: 1min 17s, total: 4min 12s
# Wall time: 2min 10s

# %%
play_game(env, model)
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/core.py:52: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   "The argument mode in render method is deprecated; "
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# Episode finished without success, accumulated reward = -17.0

# %%
# %time hist3 = train_model(env, model, total_episodes=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# resetting env. episode 1.000000, reward total was -20.000000. running mean: -20.000000
# resetting env. episode 2.000000, reward total was -21.000000. running mean: -20.010000
# resetting env. episode 3.000000, reward total was -19.000000. running mean: -19.999900
# resetting env. episode 4.000000, reward total was -21.000000. running mean: -20.009901
# resetting env. episode 5.000000, reward total was -21.000000. running mean: -20.019802
# resetting env. episode 6.000000, reward total was -21.000000. running mean: -20.029604
# resetting env. episode 7.000000, reward total was -19.000000. running mean: -20.019308
# resetting env. episode 8.000000, reward total was -20.000000. running mean: -20.019115
# resetting env. episode 9.000000, reward total was -20.000000. running mean: -20.018924
# resetting env. episode 10.000000, reward total was -21.000000. running mean: -20.028734
# resetting env. episode 11.000000, reward total was -19.000000. running mean: -20.018447
# resetting env. episode 12.000000, reward total was -21.000000. running mean: -20.028263
# resetting env. episode 13.000000, reward total was -20.000000. running mean: -20.027980
# resetting env. episode 14.000000, reward total was -21.000000. running mean: -20.037700
# resetting env. episode 15.000000, reward total was -21.000000. running mean: -20.047323
# resetting env. episode 16.000000, reward total was -20.000000. running mean: -20.046850
# resetting env. episode 17.000000, reward total was -21.000000. running mean: -20.056381
# resetting env. episode 18.000000, reward total was -21.000000. running mean: -20.065818
# resetting env. episode 19.000000, reward total was -21.000000. running mean: -20.075159
# resetting env. episode 20.000000, reward total was -20.000000. running mean: -20.074408
# resetting env. episode 21.000000, reward total was -20.000000. running mean: -20.073664
# resetting env. episode 22.000000, reward total was -21.000000. running mean: -20.082927
# resetting env. episode 23.000000, reward total was -21.000000. running mean: -20.092098
# resetting env. episode 24.000000, reward total was -20.000000. running mean: -20.091177
# resetting env. episode 25.000000, reward total was -21.000000. running mean: -20.100265
# resetting env. episode 26.000000, reward total was -19.000000. running mean: -20.089263
# resetting env. episode 27.000000, reward total was -21.000000. running mean: -20.098370
# resetting env. episode 28.000000, reward total was -19.000000. running mean: -20.087386
# resetting env. episode 29.000000, reward total was -21.000000. running mean: -20.096512
# resetting env. episode 30.000000, reward total was -21.000000. running mean: -20.105547
# resetting env. episode 31.000000, reward total was -20.000000. running mean: -20.104492
# resetting env. episode 32.000000, reward total was -21.000000. running mean: -20.113447
# resetting env. episode 33.000000, reward total was -20.000000. running mean: -20.112312
# resetting env. episode 34.000000, reward total was -21.000000. running mean: -20.121189
# resetting env. episode 35.000000, reward total was -18.000000. running mean: -20.099977
# resetting env. episode 36.000000, reward total was -20.000000. running mean: -20.098978
# resetting env. episode 37.000000, reward total was -21.000000. running mean: -20.107988
# resetting env. episode 38.000000, reward total was -21.000000. running mean: -20.116908
# resetting env. episode 39.000000, reward total was -20.000000. running mean: -20.115739
# resetting env. episode 40.000000, reward total was -21.000000. running mean: -20.124581
# resetting env. episode 41.000000, reward total was -20.000000. running mean: -20.123336
# resetting env. episode 42.000000, reward total was -19.000000. running mean: -20.112102
# resetting env. episode 43.000000, reward total was -20.000000. running mean: -20.110981
# resetting env. episode 44.000000, reward total was -21.000000. running mean: -20.119871
# resetting env. episode 45.000000, reward total was -20.000000. running mean: -20.118673
# resetting env. episode 46.000000, reward total was -20.000000. running mean: -20.117486
# resetting env. episode 47.000000, reward total was -21.000000. running mean: -20.126311
# resetting env. episode 48.000000, reward total was -21.000000. running mean: -20.135048
# resetting env. episode 49.000000, reward total was -20.000000. running mean: -20.133698
# resetting env. episode 50.000000, reward total was -21.000000. running mean: -20.142361
# resetting env. episode 51.000000, reward total was -19.000000. running mean: -20.130937
# resetting env. episode 52.000000, reward total was -20.000000. running mean: -20.129628
# resetting env. episode 53.000000, reward total was -20.000000. running mean: -20.128331
# resetting env. episode 54.000000, reward total was -21.000000. running mean: -20.137048
# resetting env. episode 55.000000, reward total was -21.000000. running mean: -20.145678
# resetting env. episode 56.000000, reward total was -19.000000. running mean: -20.134221
# resetting env. episode 57.000000, reward total was -21.000000. running mean: -20.142879
# resetting env. episode 58.000000, reward total was -21.000000. running mean: -20.151450
# resetting env. episode 59.000000, reward total was -21.000000. running mean: -20.159935
# resetting env. episode 60.000000, reward total was -18.000000. running mean: -20.138336
# resetting env. episode 61.000000, reward total was -21.000000. running mean: -20.146953
# resetting env. episode 62.000000, reward total was -19.000000. running mean: -20.135483
# resetting env. episode 63.000000, reward total was -21.000000. running mean: -20.144128
# resetting env. episode 64.000000, reward total was -20.000000. running mean: -20.142687
# resetting env. episode 65.000000, reward total was -20.000000. running mean: -20.141260
# resetting env. episode 66.000000, reward total was -20.000000. running mean: -20.139847
# resetting env. episode 67.000000, reward total was -21.000000. running mean: -20.148449
# resetting env. episode 68.000000, reward total was -21.000000. running mean: -20.156964
# resetting env. episode 69.000000, reward total was -21.000000. running mean: -20.165395
# resetting env. episode 70.000000, reward total was -21.000000. running mean: -20.173741
# resetting env. episode 71.000000, reward total was -21.000000. running mean: -20.182003
# resetting env. episode 72.000000, reward total was -21.000000. running mean: -20.190183
# resetting env. episode 73.000000, reward total was -20.000000. running mean: -20.188282
# resetting env. episode 74.000000, reward total was -20.000000. running mean: -20.186399
# resetting env. episode 75.000000, reward total was -20.000000. running mean: -20.184535
# resetting env. episode 76.000000, reward total was -21.000000. running mean: -20.192689
# resetting env. episode 77.000000, reward total was -20.000000. running mean: -20.190763
# resetting env. episode 78.000000, reward total was -21.000000. running mean: -20.198855
# resetting env. episode 79.000000, reward total was -21.000000. running mean: -20.206866
# resetting env. episode 80.000000, reward total was -20.000000. running mean: -20.204798
# resetting env. episode 81.000000, reward total was -21.000000. running mean: -20.212750
# resetting env. episode 82.000000, reward total was -20.000000. running mean: -20.210622
# resetting env. episode 83.000000, reward total was -20.000000. running mean: -20.208516
# resetting env. episode 84.000000, reward total was -21.000000. running mean: -20.216431
# resetting env. episode 85.000000, reward total was -20.000000. running mean: -20.214267
# resetting env. episode 86.000000, reward total was -21.000000. running mean: -20.222124
# resetting env. episode 87.000000, reward total was -21.000000. running mean: -20.229903
# resetting env. episode 88.000000, reward total was -21.000000. running mean: -20.237604
# resetting env. episode 89.000000, reward total was -19.000000. running mean: -20.225228
# resetting env. episode 90.000000, reward total was -20.000000. running mean: -20.222975
# resetting env. episode 91.000000, reward total was -21.000000. running mean: -20.230746
# resetting env. episode 92.000000, reward total was -21.000000. running mean: -20.238438
# resetting env. episode 93.000000, reward total was -19.000000. running mean: -20.226054
# resetting env. episode 94.000000, reward total was -20.000000. running mean: -20.223793
# resetting env. episode 95.000000, reward total was -20.000000. running mean: -20.221555
# resetting env. episode 96.000000, reward total was -21.000000. running mean: -20.229340
# resetting env. episode 97.000000, reward total was -20.000000. running mean: -20.227046
# resetting env. episode 98.000000, reward total was -20.000000. running mean: -20.224776
# resetting env. episode 99.000000, reward total was -21.000000. running mean: -20.232528
# resetting env. episode 100.000000, reward total was -20.000000. running mean: -20.230203
# CPU times: user 5min 48s, sys: 2min 36s, total: 8min 24s
# Wall time: 4min 23s

# %%
play_game(env, model)
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/core.py:52: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   "The argument mode in render method is deprecated; "
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# Episode finished without success, accumulated reward = -18.0

# %%
# import pickle
# pickle.dump(model, open('model.pkl', 'wb'))
